# %%
import pandas as pd
import numpy as np
from config import weather_api_key
from citipy import citipy
import requests

# %%
#generate 200 random numbers
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lng = np.random.uniform(low=-180.000, high=180.000, size=2000)
#create zip
lat_lng = zip(lat, lng)
#turn zip into list
coordinates = list(lat_lng)

# %%
#create empty list
cities = []

#iterate through coordinates to retrieve nearest city using citipy
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if city is unique, add to cities list
    if city not in cities:
        cities.append(city)
        
#print length of cities list
len(cities)
# Out:
# 733

# %%
#build url for requesting each cities weather from open weather
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#create empty list to store weather api data
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run and API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city info into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
                                
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that data loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | fukue
# Processing Record 3 of Set 1 | swellendam
# Processing Record 4 of Set 1 | malu cu flori
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | san cristobal
# Processing Record 7 of Set 1 | winchester
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | mossendjo
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | dali
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | sri aman
# Processing Record 17 of Set 1 | qeshm
# Processing Record 18 of Set 1 | dillon
# Processing Record 19 of Set 1 | pundaguitan
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | umm lajj
# Processing Record 22 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 1 | tazmalt
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | kensington
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | kharp
# Processing Record 32 of Set 1 | bethlehem
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | clyde river
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | kalmunai
# Processing Record 45 of Set 1 | dongsheng
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | ambulu
# Processing Record 48 of Set 1 | orsha
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | balancan
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | saint-augustin
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | kenora
# Processing Record 8 of Set 2 | talnakh
# Processing Record 9 of Set 2 | goderich
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | narsaq
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | melito di porto salvo
# Processing Record 15 of Set 2 | banda aceh
# Processing Record 16 of Set 2 | esperance
# Processing Record 17 of Set 2 | bowen
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | hofn
# Processing Record 21 of Set 2 | nalut
# Processing Record 22 of Set 2 | marsh harbour
# Processing Record 23 of Set 2 | aklavik
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | san quintin
# Processing Record 29 of Set 2 | kununurra
# Processing Record 30 of Set 2 | salalah
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | katsuura
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | longyearbyen
# Processing Record 36 of Set 2 | coahuayana
# Processing Record 37 of Set 2 | soyo
# Processing Record 38 of Set 2 | estevan
# Processing Record 39 of Set 2 | novo aripuana
# Processing Record 40 of Set 2 | cerritos
# Processing Record 41 of Set 2 | zhangjiakou
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | brindisi
# Processing Record 44 of Set 2 | aksu
# Processing Record 45 of Set 2 | eyl
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 2 | nanortalik
# Processing Record 49 of Set 2 | albany
# Processing Record 50 of Set 2 | chippewa falls
# Processing Record 1 of Set 3 | yelizovo
# Processing Record 2 of Set 3 | sao filipe
# Processing Record 3 of Set 3 | hokitika
# Processing Record 4 of Set 3 | praia da vitoria
# Processing Record 5 of Set 3 | usinsk
# Processing Record 6 of Set 3 | san andres
# Processing Record 7 of Set 3 | camacha
# Processing Record 8 of Set 3 | la palma
# Processing Record 9 of Set 3 | tokur
# Processing Record 10 of Set 3 | caravelas
# Processing Record 11 of Set 3 | praya
# Processing Record 12 of Set 3 | storforshei
# Processing Record 13 of Set 3 | sao jose da coroa grande
# Processing Record 14 of Set 3 | harper
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | yerbogachen
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | clinton
# Processing Record 19 of Set 3 | tutayev
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | vila franca do campo
# Processing Record 22 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 3 | poso
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | champerico
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | barrow
# Processing Record 32 of Set 3 | curaca
# Processing Record 33 of Set 3 | pareora
# Processing Record 34 of Set 3 | omboue
# Processing Record 35 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 3 | laurel
# Processing Record 37 of Set 3 | tabas
# Processing Record 38 of Set 3 | oranjestad
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | taree
# Processing Record 41 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 3 | axim
# Processing Record 43 of Set 3 | bandarbeyla
# Processing Record 44 of Set 3 | lasa
# Processing Record 45 of Set 3 | carbondale
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | pangkalanbuun
# Processing Record 48 of Set 3 | ancud
# Processing Record 49 of Set 3 | amuntai
# Processing Record 50 of Set 3 | saskylakh
# Processing Record 1 of Set 4 | baleni
# Processing Record 2 of Set 4 | pontes e lacerda
# Processing Record 3 of Set 4 | sioux lookout
# Processing Record 4 of Set 4 | ahipara
# Processing Record 5 of Set 4 | korla
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | polunochnoye
# Processing Record 8 of Set 4 | richards bay
# Processing Record 9 of Set 4 | sinnamary
# Processing Record 10 of Set 4 | namibe
# Processing Record 11 of Set 4 | quatre cocos
# Processing Record 12 of Set 4 | kamarion
# Processing Record 13 of Set 4 | berlevag
# Processing Record 14 of Set 4 | vostok
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | kisanga
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | bainbridge
# Processing Record 19 of Set 4 | smithers
# Processing Record 20 of Set 4 | airai
# Processing Record 21 of Set 4 | pflugerville
# Processing Record 22 of Set 4 | jiwani
# Processing Record 23 of Set 4 | safaga
# Processing Record 24 of Set 4 | iraquara
# Processing Record 25 of Set 4 | padang
# Processing Record 26 of Set 4 | ribeira grande
# Processing Record 27 of Set 4 | vardo
# Processing Record 28 of Set 4 | shetpe
# Processing Record 29 of Set 4 | arroyo
# Processing Record 30 of Set 4 | bosaso
# Processing Record 31 of Set 4 | klaksvik
# Processing Record 32 of Set 4 | hastings
# Processing Record 33 of Set 4 | raton
# Processing Record 34 of Set 4 | teahupoo
# Processing Record 35 of Set 4 | faanui
# Processing Record 36 of Set 4 | zhuhai
# Processing Record 37 of Set 4 | koumac
# Processing Record 38 of Set 4 | ewa beach
# Processing Record 39 of Set 4 | tashigang
# Processing Record 40 of Set 4 | varkaus
# Processing Record 41 of Set 4 | avera
# Processing Record 42 of Set 4 | east london
# Processing Record 43 of Set 4 | bellevue
# Processing Record 44 of Set 4 | kayerkan
# Processing Record 45 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 46 of Set 4 | bilma
# Processing Record 47 of Set 4 | castro
# Processing Record 48 of Set 4 | portland
# Processing Record 49 of Set 4 | khandyga
# Processing Record 50 of Set 4 | gouyave
# Processing Record 1 of Set 5 | tailai
# Processing Record 2 of Set 5 | newport
# Processing Record 3 of Set 5 | tairua
# Processing Record 4 of Set 5 | college
# Processing Record 5 of Set 5 | saint-philippe
# Processing Record 6 of Set 5 | emba
# Processing Record 7 of Set 5 | pascagoula
# Processing Record 8 of Set 5 | peleduy
# Processing Record 9 of Set 5 | margaritas
# Processing Record 10 of Set 5 | moron
# Processing Record 11 of Set 5 | lakes entrance
# Processing Record 12 of Set 5 | port moresby
# Processing Record 13 of Set 5 | caledonia
# Processing Record 14 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 5 | price
# Processing Record 16 of Set 5 | salvador
# Processing Record 17 of Set 5 | joao neiva
# Processing Record 18 of Set 5 | omutinskoye
# City not found. Skipping...
# Processing Record 19 of Set 5 | lima
# Processing Record 20 of Set 5 | puerto escondido
# Processing Record 21 of Set 5 | mar del plata
# Processing Record 22 of Set 5 | lethem
# Processing Record 23 of Set 5 | sept-iles
# Processing Record 24 of Set 5 | manzhouli
# Processing Record 25 of Set 5 | kemijarvi
# Processing Record 26 of Set 5 | domoni
# Processing Record 27 of Set 5 | porbandar
# Processing Record 28 of Set 5 | alofi
# Processing Record 29 of Set 5 | tuatapere
# Processing Record 30 of Set 5 | port-gentil
# Processing Record 31 of Set 5 | tazovskiy
# Processing Record 32 of Set 5 | saint anthony
# Processing Record 33 of Set 5 | dingle
# Processing Record 34 of Set 5 | aitape
# Processing Record 35 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 5 | karratha
# Processing Record 37 of Set 5 | kargasok
# Processing Record 38 of Set 5 | nizhniy tsasuchey
# Processing Record 39 of Set 5 | sylvan lake
# Processing Record 40 of Set 5 | ilheus
# Processing Record 41 of Set 5 | kruisfontein
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | waverly
# Processing Record 44 of Set 5 | urumqi
# Processing Record 45 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 5 | tura
# Processing Record 47 of Set 5 | hasaki
# Processing Record 48 of Set 5 | fort wellington
# Processing Record 49 of Set 5 | santa isabel do rio negro
# Processing Record 50 of Set 5 | asau
# Processing Record 1 of Set 6 | sumter
# Processing Record 2 of Set 6 | grand gaube
# Processing Record 3 of Set 6 | tacuarembo
# Processing Record 4 of Set 6 | brae
# Processing Record 5 of Set 6 | fortuna
# Processing Record 6 of Set 6 | effium
# Processing Record 7 of Set 6 | svetogorsk
# Processing Record 8 of Set 6 | westport
# Processing Record 9 of Set 6 | henties bay
# Processing Record 10 of Set 6 | vrangel
# Processing Record 11 of Set 6 | victoria
# Processing Record 12 of Set 6 | zhangye
# Processing Record 13 of Set 6 | broome
# Processing Record 14 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 6 | lazaro cardenas
# Processing Record 17 of Set 6 | mount gambier
# Processing Record 18 of Set 6 | ukiah
# Processing Record 19 of Set 6 | kotli loharan
# Processing Record 20 of Set 6 | oktyabrskiy
# Processing Record 21 of Set 6 | mazatlan
# Processing Record 22 of Set 6 | jalu
# Processing Record 23 of Set 6 | weinan
# Processing Record 24 of Set 6 | omsukchan
# Processing Record 25 of Set 6 | lompoc
# Processing Record 26 of Set 6 | asfi
# Processing Record 27 of Set 6 | shingu
# Processing Record 28 of Set 6 | paita
# Processing Record 29 of Set 6 | atherton
# Processing Record 30 of Set 6 | hambantota
# Processing Record 31 of Set 6 | puerto madero
# Processing Record 32 of Set 6 | berdigestyakh
# Processing Record 33 of Set 6 | jandaia do sul
# Processing Record 34 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 35 of Set 6 | blyth
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | egvekinot
# Processing Record 38 of Set 6 | eureka
# Processing Record 39 of Set 6 | vitim
# Processing Record 40 of Set 6 | palmer
# Processing Record 41 of Set 6 | senmonorom
# City not found. Skipping...
# Processing Record 42 of Set 6 | ocean city
# Processing Record 43 of Set 6 | alugan
# Processing Record 44 of Set 6 | kazachinskoye
# Processing Record 45 of Set 6 | miracema do tocantins
# Processing Record 46 of Set 6 | nuuk
# Processing Record 47 of Set 6 | morros
# Processing Record 48 of Set 6 | plettenberg bay
# Processing Record 49 of Set 6 | thompson
# Processing Record 50 of Set 6 | suez
# Processing Record 1 of Set 7 | najran
# Processing Record 2 of Set 7 | dudinka
# Processing Record 3 of Set 7 | suzu
# City not found. Skipping...
# Processing Record 4 of Set 7 | port lincoln
# Processing Record 5 of Set 7 | colares
# Processing Record 6 of Set 7 | khorixas
# Processing Record 7 of Set 7 | sitka
# Processing Record 8 of Set 7 | hovd
# Processing Record 9 of Set 7 | casa grande
# Processing Record 10 of Set 7 | nemuro
# Processing Record 11 of Set 7 | cap-aux-meules
# Processing Record 12 of Set 7 | kaili
# Processing Record 13 of Set 7 | samana
# Processing Record 14 of Set 7 | tekkali
# Processing Record 15 of Set 7 | lorengau
# Processing Record 16 of Set 7 | lishui
# Processing Record 17 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 7 | port blair
# Processing Record 19 of Set 7 | pemangkat
# Processing Record 20 of Set 7 | san diego
# Processing Record 21 of Set 7 | wajir
# Processing Record 22 of Set 7 | north platte
# Processing Record 23 of Set 7 | balkanabat
# Processing Record 24 of Set 7 | atbasar
# Processing Record 25 of Set 7 | fare
# Processing Record 26 of Set 7 | ziway
# Processing Record 27 of Set 7 | hamilton
# Processing Record 28 of Set 7 | gayny
# Processing Record 29 of Set 7 | talagang
# Processing Record 30 of Set 7 | santiago de cuba
# Processing Record 31 of Set 7 | novyye burasy
# Processing Record 32 of Set 7 | lavrentiya
# Processing Record 33 of Set 7 | nouadhibou
# Processing Record 34 of Set 7 | marsabit
# Processing Record 35 of Set 7 | naze
# Processing Record 36 of Set 7 | burnie
# Processing Record 37 of Set 7 | villarrica
# Processing Record 38 of Set 7 | denpasar
# Processing Record 39 of Set 7 | gasa
# Processing Record 40 of Set 7 | batemans bay
# Processing Record 41 of Set 7 | riyadh
# Processing Record 42 of Set 7 | stip
# City not found. Skipping...
# Processing Record 43 of Set 7 | manzanillo
# Processing Record 44 of Set 7 | jarjis
# City not found. Skipping...
# Processing Record 45 of Set 7 | kirakira
# Processing Record 46 of Set 7 | muros
# Processing Record 47 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 7 | republic
# Processing Record 49 of Set 7 | grande-riviere
# City not found. Skipping...
# Processing Record 50 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 8 | qaqortoq
# Processing Record 2 of Set 8 | tocopilla
# Processing Record 3 of Set 8 | hami
# Processing Record 4 of Set 8 | kahului
# Processing Record 5 of Set 8 | popondetta
# Processing Record 6 of Set 8 | khorinsk
# Processing Record 7 of Set 8 | sibolga
# Processing Record 8 of Set 8 | gainesville
# Processing Record 9 of Set 8 | juba
# Processing Record 10 of Set 8 | vila velha
# Processing Record 11 of Set 8 | yulara
# Processing Record 12 of Set 8 | arraias
# Processing Record 13 of Set 8 | coos bay
# Processing Record 14 of Set 8 | laguna
# Processing Record 15 of Set 8 | meulaboh
# Processing Record 16 of Set 8 | yar-sale
# Processing Record 17 of Set 8 | tarakan
# Processing Record 18 of Set 8 | gornoye loo
# Processing Record 19 of Set 8 | coquimbo
# Processing Record 20 of Set 8 | komsomolskiy
# Processing Record 21 of Set 8 | beringovskiy
# Processing Record 22 of Set 8 | mpika
# Processing Record 23 of Set 8 | karpathos
# Processing Record 24 of Set 8 | maragogi
# Processing Record 25 of Set 8 | tiquisio
# Processing Record 26 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 8 | mukhen
# Processing Record 28 of Set 8 | arya
# Processing Record 29 of Set 8 | haines junction
# Processing Record 30 of Set 8 | rawson
# Processing Record 31 of Set 8 | bairiki
# Processing Record 32 of Set 8 | caernarfon
# Processing Record 33 of Set 8 | shimoda
# Processing Record 34 of Set 8 | tougan
# Processing Record 35 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 8 | dunedin
# Processing Record 37 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 8 | itarema
# Processing Record 39 of Set 8 | carutapera
# Processing Record 40 of Set 8 | aberdeen
# Processing Record 41 of Set 8 | puerto leguizamo
# Processing Record 42 of Set 8 | van
# Processing Record 43 of Set 8 | shafranovo
# Processing Record 44 of Set 8 | raudeberg
# Processing Record 45 of Set 8 | kardla
# Processing Record 46 of Set 8 | glarus
# Processing Record 47 of Set 8 | bathsheba
# Processing Record 48 of Set 8 | russell
# Processing Record 49 of Set 8 | ilulissat
# Processing Record 50 of Set 8 | pedroso
# Processing Record 1 of Set 9 | shubarkuduk
# Processing Record 2 of Set 9 | midland
# Processing Record 3 of Set 9 | rundu
# Processing Record 4 of Set 9 | oga
# Processing Record 5 of Set 9 | cam ranh
# Processing Record 6 of Set 9 | sao joao da barra
# Processing Record 7 of Set 9 | pangnirtung
# Processing Record 8 of Set 9 | torbay
# Processing Record 9 of Set 9 | evanston
# Processing Record 10 of Set 9 | terrace bay
# Processing Record 11 of Set 9 | acapulco
# Processing Record 12 of Set 9 | olinda
# Processing Record 13 of Set 9 | itoman
# Processing Record 14 of Set 9 | kaeo
# Processing Record 15 of Set 9 | khartoum
# Processing Record 16 of Set 9 | chernihiv
# Processing Record 17 of Set 9 | bac lieu
# Processing Record 18 of Set 9 | okhotsk
# Processing Record 19 of Set 9 | saint-pierre
# Processing Record 20 of Set 9 | pitimbu
# Processing Record 21 of Set 9 | colesberg
# Processing Record 22 of Set 9 | hayato
# City not found. Skipping...
# Processing Record 23 of Set 9 | arinos
# Processing Record 24 of Set 9 | maceio
# Processing Record 25 of Set 9 | ji-parana
# City not found. Skipping...
# Processing Record 26 of Set 9 | tyazhinskiy
# Processing Record 27 of Set 9 | pisco
# Processing Record 28 of Set 9 | kampot
# Processing Record 29 of Set 9 | kijang
# Processing Record 30 of Set 9 | cullen
# Processing Record 31 of Set 9 | hervey bay
# Processing Record 32 of Set 9 | panzhihua
# Processing Record 33 of Set 9 | yibin
# Processing Record 34 of Set 9 | katherine
# Processing Record 35 of Set 9 | licheng
# Processing Record 36 of Set 9 | kalangala
# Processing Record 37 of Set 9 | sorong
# Processing Record 38 of Set 9 | fort smith
# Processing Record 39 of Set 9 | vadu crisului
# Processing Record 40 of Set 9 | geraldton
# Processing Record 41 of Set 9 | eldorado
# Processing Record 42 of Set 9 | paamiut
# Processing Record 43 of Set 9 | carman
# Processing Record 44 of Set 9 | cairns
# Processing Record 45 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 9 | solnechnyy
# Processing Record 47 of Set 9 | husavik
# Processing Record 48 of Set 9 | kysyl-syr
# Processing Record 49 of Set 9 | touros
# Processing Record 50 of Set 9 | hoganas
# Processing Record 1 of Set 10 | callaway
# Processing Record 2 of Set 10 | gat
# Processing Record 3 of Set 10 | jacmel
# Processing Record 4 of Set 10 | calahorra
# Processing Record 5 of Set 10 | halifax
# Processing Record 6 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 10 | asaba
# Processing Record 8 of Set 10 | kaitangata
# Processing Record 9 of Set 10 | sherpur
# Processing Record 10 of Set 10 | lowestoft
# Processing Record 11 of Set 10 | lesnoy
# Processing Record 12 of Set 10 | vila
# Processing Record 13 of Set 10 | mersing
# Processing Record 14 of Set 10 | maniitsoq
# Processing Record 15 of Set 10 | kerzhenets
# City not found. Skipping...
# Processing Record 16 of Set 10 | saint george
# Processing Record 17 of Set 10 | ojinaga
# Processing Record 18 of Set 10 | xining
# Processing Record 19 of Set 10 | sebeta
# Processing Record 20 of Set 10 | boone
# Processing Record 21 of Set 10 | quang ngai
# Processing Record 22 of Set 10 | kavieng
# Processing Record 23 of Set 10 | bursa
# Processing Record 24 of Set 10 | kyabram
# Processing Record 25 of Set 10 | buchanan
# Processing Record 26 of Set 10 | olafsvik
# Processing Record 27 of Set 10 | guerrero negro
# Processing Record 28 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 10 | jumla
# Processing Record 31 of Set 10 | falavarjan
# Processing Record 32 of Set 10 | irati
# Processing Record 33 of Set 10 | pahrump
# Processing Record 34 of Set 10 | cedar city
# Processing Record 35 of Set 10 | davila
# Processing Record 36 of Set 10 | chumikan
# Processing Record 37 of Set 10 | portree
# Processing Record 38 of Set 10 | petropavlovka
# Processing Record 39 of Set 10 | lagoa
# Processing Record 40 of Set 10 | raga
# Processing Record 41 of Set 10 | gubkinskiy
# Processing Record 42 of Set 10 | tarrega
# Processing Record 43 of Set 10 | samandag
# Processing Record 44 of Set 10 | shache
# Processing Record 45 of Set 10 | karachi
# Processing Record 46 of Set 10 | bocaranga
# City not found. Skipping...
# Processing Record 47 of Set 10 | colonial heights
# Processing Record 48 of Set 10 | antofagasta
# Processing Record 49 of Set 10 | aketi
# Processing Record 50 of Set 10 | williams lake
# Processing Record 1 of Set 11 | rio gallegos
# Processing Record 2 of Set 11 | luancheng
# Processing Record 3 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 4 of Set 11 | port hedland
# Processing Record 5 of Set 11 | gizo
# Processing Record 6 of Set 11 | ginda
# Processing Record 7 of Set 11 | oktyabrskoye
# Processing Record 8 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 11 | mahajanga
# Processing Record 10 of Set 11 | north bend
# Processing Record 11 of Set 11 | hay river
# Processing Record 12 of Set 11 | bonthe
# Processing Record 13 of Set 11 | tiznit
# Processing Record 14 of Set 11 | biltine
# Processing Record 15 of Set 11 | linhares
# Processing Record 16 of Set 11 | ketchikan
# Processing Record 17 of Set 11 | ivanava
# Processing Record 18 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 11 | ahuimanu
# Processing Record 21 of Set 11 | sinjai
# Processing Record 22 of Set 11 | santa vitoria do palmar
# Processing Record 23 of Set 11 | horsham
# Processing Record 24 of Set 11 | mezen
# Processing Record 25 of Set 11 | jibuti
# Processing Record 26 of Set 11 | talcahuano
# Processing Record 27 of Set 11 | tamworth
# Processing Record 28 of Set 11 | athabasca
# Processing Record 29 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 11 | vanimo
# Processing Record 31 of Set 11 | nago
# Processing Record 32 of Set 11 | birin
# Processing Record 33 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 34 of Set 11 | catia la mar
# Processing Record 35 of Set 11 | sherlovaya gora
# Processing Record 36 of Set 11 | aliwal north
# Processing Record 37 of Set 11 | veraval
# Processing Record 38 of Set 11 | mugumu
# Processing Record 39 of Set 11 | majene
# Processing Record 40 of Set 11 | arlit
# Processing Record 41 of Set 11 | poum
# Processing Record 42 of Set 11 | ihlow
# Processing Record 43 of Set 11 | saint-paul
# Processing Record 44 of Set 11 | sakaiminato
# Processing Record 45 of Set 11 | tabou
# Processing Record 46 of Set 11 | mahibadhoo
# Processing Record 47 of Set 11 | buraydah
# Processing Record 48 of Set 11 | neyshabur
# Processing Record 49 of Set 11 | amazar
# Processing Record 50 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 12 | canavieiras
# Processing Record 2 of Set 12 | tautira
# Processing Record 3 of Set 12 | penzance
# Processing Record 4 of Set 12 | matamoros
# Processing Record 5 of Set 12 | yamada
# Processing Record 6 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 12 | turukhansk
# Processing Record 8 of Set 12 | norman wells
# Processing Record 9 of Set 12 | andros
# Processing Record 10 of Set 12 | colatina
# Processing Record 11 of Set 12 | nhulunbuy
# Processing Record 12 of Set 12 | along
# Processing Record 13 of Set 12 | ushumun
# Processing Record 14 of Set 12 | burica
# City not found. Skipping...
# Processing Record 15 of Set 12 | nome
# Processing Record 16 of Set 12 | dukhovshchina
# Processing Record 17 of Set 12 | mondlo
# Processing Record 18 of Set 12 | mao
# Processing Record 19 of Set 12 | karaton
# Processing Record 20 of Set 12 | ust-omchug
# Processing Record 21 of Set 12 | rio das ostras
# Processing Record 22 of Set 12 | ningbo
# Processing Record 23 of Set 12 | kidal
# Processing Record 24 of Set 12 | filingue
# Processing Record 25 of Set 12 | verkh-usugli
# Processing Record 26 of Set 12 | labuhan
# Processing Record 27 of Set 12 | mbeya
# Processing Record 28 of Set 12 | pacific grove
# Processing Record 29 of Set 12 | te anau
# Processing Record 30 of Set 12 | coihaique
# Processing Record 31 of Set 12 | magaria
# Processing Record 32 of Set 12 | svetlyy
# Processing Record 33 of Set 12 | copiapo
# Processing Record 34 of Set 12 | quballat
# Processing Record 35 of Set 12 | leonidovo
# Processing Record 36 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 12 | taoudenni
# Processing Record 39 of Set 12 | mandalgovi
# Processing Record 40 of Set 12 | quzhou
# Processing Record 41 of Set 12 | lugazi
# Processing Record 42 of Set 12 | mogadishu
# Processing Record 43 of Set 12 | colac
# Processing Record 44 of Set 12 | half moon bay
# Processing Record 45 of Set 12 | kabare
# Processing Record 46 of Set 12 | rocha
# Processing Record 47 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 48 of Set 12 | hualmay
# Processing Record 49 of Set 12 | maamba
# Processing Record 50 of Set 12 | xichang
# Processing Record 1 of Set 13 | fershampenuaz
# Processing Record 2 of Set 13 | honningsvag
# Processing Record 3 of Set 13 | qafsah
# City not found. Skipping...
# Processing Record 4 of Set 13 | ust-nera
# Processing Record 5 of Set 13 | mount pleasant
# Processing Record 6 of Set 13 | port hardy
# Processing Record 7 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 13 | mozarlandia
# Processing Record 9 of Set 13 | leshukonskoye
# Processing Record 10 of Set 13 | stepnogorsk
# Processing Record 11 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 13 | christchurch
# Processing Record 13 of Set 13 | ryde
# Processing Record 14 of Set 13 | baykit
# Processing Record 15 of Set 13 | singapore
# Processing Record 16 of Set 13 | alyangula
# Processing Record 17 of Set 13 | vetapalem
# Processing Record 18 of Set 13 | worland
# Processing Record 19 of Set 13 | cayenne
# Processing Record 20 of Set 13 | ngunguru
# Processing Record 21 of Set 13 | tashla
# Processing Record 22 of Set 13 | totness
# Processing Record 23 of Set 13 | zamardi
# Processing Record 24 of Set 13 | roald
# Processing Record 25 of Set 13 | bonoua
# Processing Record 26 of Set 13 | falmouth
# Processing Record 27 of Set 13 | cabedelo
# Processing Record 28 of Set 13 | wasilla
# Processing Record 29 of Set 13 | sheltozero
# Processing Record 30 of Set 13 | camacari
# Processing Record 31 of Set 13 | aykhal
# Processing Record 32 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 13 | la rioja
# Processing Record 34 of Set 13 | kipini
# Processing Record 35 of Set 13 | vestmannaeyjar
# Processing Record 36 of Set 13 | chara
# Processing Record 37 of Set 13 | havelock
# Processing Record 38 of Set 13 | luanda
# Processing Record 39 of Set 13 | agirish
# Processing Record 40 of Set 13 | acarau
# Processing Record 41 of Set 13 | longhua
# Processing Record 42 of Set 13 | pavlovka
# Processing Record 43 of Set 13 | magalia
# Processing Record 44 of Set 13 | kutum
# Processing Record 45 of Set 13 | khani
# Processing Record 46 of Set 13 | balclutha
# Processing Record 47 of Set 13 | manzil salim
# Processing Record 48 of Set 13 | caranavi
# Processing Record 49 of Set 13 | dondo
# Processing Record 50 of Set 13 | emerald
# Processing Record 1 of Set 14 | grosuplje
# Processing Record 2 of Set 14 | verkhniy lomov
# Processing Record 3 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 14 | bayreuth
# Processing Record 5 of Set 14 | mumbwa
# Processing Record 6 of Set 14 | yumen
# Processing Record 7 of Set 14 | saint-francois
# Processing Record 8 of Set 14 | ambilobe
# Processing Record 9 of Set 14 | fairlie
# Processing Record 10 of Set 14 | weatherford
# Processing Record 11 of Set 14 | igrejinha
# Processing Record 12 of Set 14 | tera
# Processing Record 13 of Set 14 | urdoma
# Processing Record 14 of Set 14 | tabuk
# Processing Record 15 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 16 of Set 14 | shitanjing
# Processing Record 17 of Set 14 | the pas
# Processing Record 18 of Set 14 | matara
# Processing Record 19 of Set 14 | mapalad
# Processing Record 20 of Set 14 | svetlaya
# Processing Record 21 of Set 14 | luwuk
# Processing Record 22 of Set 14 | baruun-urt
# Processing Record 23 of Set 14 | sivas
# Processing Record 24 of Set 14 | la macarena
# Processing Record 25 of Set 14 | ternate
# Processing Record 26 of Set 14 | milkovo
# Processing Record 27 of Set 14 | beloha
# Processing Record 28 of Set 14 | zhigansk
# Processing Record 29 of Set 14 | massape
# Processing Record 30 of Set 14 | margate
# Processing Record 31 of Set 14 | presidencia roque saenz pena
# Processing Record 32 of Set 14 | teknaf
# Processing Record 33 of Set 14 | samoded
# Processing Record 34 of Set 14 | sechura
# Processing Record 35 of Set 14 | barentu
# Processing Record 36 of Set 14 | casino
# Processing Record 37 of Set 14 | kazanskoye
# Processing Record 38 of Set 14 | cap malheureux
# Processing Record 39 of Set 14 | saint-louis
# Processing Record 40 of Set 14 | margherita
# Processing Record 41 of Set 14 | isa khel
# Processing Record 42 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 43 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 14 | ozark
# Processing Record 45 of Set 14 | lucea
# Processing Record 46 of Set 14 | adrar
# Processing Record 47 of Set 14 | chabahar
# Processing Record 48 of Set 14 | pouembout
# Processing Record 49 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 14 | kachiry
# Processing Record 1 of Set 15 | kamenka
# Processing Record 2 of Set 15 | vao
# Processing Record 3 of Set 15 | fulitun
# City not found. Skipping...
# Processing Record 4 of Set 15 | ratnagiri
# Processing Record 5 of Set 15 | chuzhou
# Processing Record 6 of Set 15 | the valley
# Processing Record 7 of Set 15 | bakchar
# Processing Record 8 of Set 15 | puerto colombia
# Processing Record 9 of Set 15 | zheleznodorozhnyy
# Processing Record 10 of Set 15 | ewo
# Processing Record 11 of Set 15 | korhogo
# Processing Record 12 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 13 of Set 15 | deputatskiy
# Processing Record 14 of Set 15 | tagab
# Processing Record 15 of Set 15 | ilhabela
# Processing Record 16 of Set 15 | krutikha
# Processing Record 17 of Set 15 | marzuq
# Processing Record 18 of Set 15 | sao felix do xingu
# Processing Record 19 of Set 15 | kinablangan
# Processing Record 20 of Set 15 | coffs harbour
# Processing Record 21 of Set 15 | barcelona
# Processing Record 22 of Set 15 | andenes
# Processing Record 23 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 15 | alta floresta
# Processing Record 25 of Set 15 | mongu
# Processing Record 26 of Set 15 | mitzic
# Processing Record 27 of Set 15 | bom jesus da lapa
# Processing Record 28 of Set 15 | cockburn town
# Processing Record 29 of Set 15 | cosala
# Processing Record 30 of Set 15 | boke
# Processing Record 31 of Set 15 | ginir
# Processing Record 32 of Set 15 | havre-saint-pierre
# Processing Record 33 of Set 15 | labrea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 670

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Busselton      AU -33.65  115.33     79.00        31          10
# 1          Fukue      JP  32.69  128.84     71.60        49           0
# 2     Swellendam      ZA -34.02   20.44     55.40        87          63
# 3  Malu Cu Flori      RO  45.15   25.20     39.00        81           0
# 4        Qaanaaq      GL  77.48  -69.36     29.75        85          76
# 5  San Cristobal      VE   7.77  -72.22     66.36        84          96
# 6     Winchester      GB  51.07   -1.32     55.99        93         100
# 7      Upernavik      GL  72.79  -56.15     33.78        88         100
# 8         Dikson      RU  73.51   80.55     24.57        94          98
# 9         Atuona      PF  -9.80 -139.03     78.33        78           1
#
#    Wind Speed Current Description
# 0        8.25           clear sky
# 1       13.87           clear sky
# 2        9.17       broken clouds
# 3        3.02           clear sky
# 4        8.16       broken clouds
# 5        1.50          light rain
# 6       14.99          light rain
# 7       10.20     overcast clouds
# 8       15.95     overcast clouds
# 9       19.73          light rain

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
